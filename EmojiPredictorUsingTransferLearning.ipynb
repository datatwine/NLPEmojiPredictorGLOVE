# %%
import numpy as np
import pandas as pd
import emoji as emoji
print('Imported Successfully!')
# Out:
# Imported Successfully!

# %%
print(emoji.EMOJI_DATA)
print(len(emoji.EMOJI_DATA))
# Out:
# {'🥇': {'en': ':1st_place_medal:', 'status': 2, 'E': 3, 'de': ':goldmedaille:', 'es': ':medalla_de_oro:', 'fr': ':médaille_d’or:', 'ja': ':金メダル:', 'ko': ':금메달:', 'pt': ':medalha_de_ouro:', 'it': ':medaglia_d’oro:', 'fa': ':مدال_طلا:', 'id': ':medali_emas:', 'zh': ':金牌:'}, '🥈': {'en': ':2nd_place_medal:', 'status': 2, 'E': 3, 'de': ':silbermedaille:', 'es': ':medalla_de_plata:', 'fr': ':médaille_d’argent:', 'ja': ':銀メダル:', 'ko': ':은메달:', 'pt': ':medalha_de_prata:', 'it': ':medaglia_d’argento:', 'fa': ':مدال_نقره:', 'id': ':medali_perak:', 'zh': ':银牌:'}, '🥉': {'en': ':3rd_place_medal:', 'status': 2, 'E': 3, 'de': ':bronzemedaille:', 'es': ':medalla_de_bronce:', 'fr': ':médaille_de_bronze:', 'ja': ':銅メダル:', 'ko': ':동메달:', 'pt': ':medalha_de_bronze:', 'it': ':medaglia_di_bronzo:', 'fa': ':مدال_برنز:', 'id': ':medali_perunggu:', 'zh': ':铜牌:'}, '🆎': {'en': ':AB_button_(blood_type):', 'status': 2, 'E': 0.6, 'alias': [':ab:'], 'de': ':großbuchstaben_ab_in_rotem_quadrat:', 'es': ':grupo_sanguí
# ...

# %%
emoji_dictionary = {"0": "\u2764\uFE0F",
                    "1": ":baseball:",
                    "2": ":beaming_face_with_smiling_eyes:",
                    "3": ":downcast_face_with_sweat:",
                    "4": ":fork_and_knife:",
                   }
for e in emoji_dictionary.values():
  print(emoji.emojize(e))
# Out:
# ❤️
# ⚾
# 😁
# 😓
# 🍴

# %%
# Load the Training and Testing dataset
train = pd.read_csv(r'C:\Users\91974\Documents\Datasets\Emoji_Predictor\train_emoji.csv',header=None)
test = pd.read_csv(r'C:\Users\91974\Documents\Datasets\Emoji_Predictor\test_emoji.csv',header=None)

data = train.values
for i in range(10):
    print(data[i][0],emoji.emojize(emoji_dictionary[str(data[i][1])]))
# Out:
# never talk to me again 😓
# I am proud of your achievements 😁
# It is the worst day in my life 😓
# Miss you so much ❤️
# food is life 🍴
# I love you mum ❤️
# Stop saying bullshit 😓
# congratulations on your acceptance 😁
# The assignment is too long  😓
# I want to go play ⚾

# %%
#Load GLOVE word embeddings
embeddings = {}
with open(r'C:\Users\91974\Documents\Datasets\Emoji_Predictor\Glove_Embeddings\glove.6B.50d.txt',encoding='utf-8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coeffs = np.asarray(values[1:],dtype='float32')
        embeddings[word] = coeffs

print(embeddings['eat'])
print(embeddings['play'])
# Out:
# [ 6.4295e-01 -4.2946e-01 -5.4277e-01 -1.0307e+00  1.2056e+00 -2.7174e-01
#  -6.3561e-01 -1.5065e-02  3.7856e-01  4.6474e-02 -1.3102e-01  6.0500e-01
#   1.6391e+00  2.3940e-01  1.2128e+00  8.3178e-01  7.3893e-01  1.5200e-01
#  -1.4175e-01 -8.8384e-01  2.0829e-02 -3.2545e-01  1.8035e+00  1.0045e+00
#   5.8484e-01 -6.2031e-01 -4.3296e-01  2.3562e-01  1.3027e+00 -8.1264e-01
#   2.3158e+00  1.1030e+00 -6.0608e-01  1.0101e+00 -2.2426e-01  1.8908e-02
#  -1.0931e-01  3.8350e-01  7.7362e-01 -8.1927e-02 -3.4040e-01 -1.5143e-03
#  -5.6640e-02  8.7359e-01  1.4805e+00  6.9421e-01 -3.0966e-01 -9.0826e-01
#   3.7277e-03  8.4550e-01]
# [-0.73571   0.19937  -0.89408   0.36406  -0.20246  -0.034324 -0.63138
#   0.76669  -0.94343   0.65883   0.049478  0.55608  -1.2809    0.44575
#   0.73791   0.014728  0.80956  -0.35516  -1.0248   -0.13845  -0.47632
#   0.32001   0.35023   0.77794   0.60233  -1.2321    0.043144 -0.41347
#   0.34533  -1.3093    3.4681    0.9882    0.038253 -0.33672   0.30999
# ...

# %%
from keras.utils import to_categorical
XT = train[0]
Xt = test[0]

YT = to_categorical(train[1])
Yt = to_categorical(test[1])


print(XT.shape)
print(Xt.shape)
print(YT.shape)
print(Yt.shape)
# Out:
# C:\Users\91974\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# (132,)
# (56,)
# (132, 5)
# (56, 5)

# %%
#Converting Sentences into Vectors
def getOutputEmbeddings(X):
    
    embedding_matrix_output = np.zeros((X.shape[0],10,50))
    for ix in range(X.shape[0]):
        X[ix] = X[ix].split()
        for jx in range(len(X[ix])):
            embedding_matrix_output[ix][jx] = embeddings[X[ix][jx].lower()]
            
    return embedding_matrix_output

emb_XT = getOutputEmbeddings(XT)
emb_Xt = getOutputEmbeddings(Xt)
print(emb_XT.shape)
print(emb_Xt.shape)
# Out:
# (132, 10, 50)
# (56, 10, 50)
# C:\Users\91974\AppData\Local\Temp/ipykernel_17044/1721718517.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[ix] = X[ix].split()

# %%
#Creating Model Architecture 
from keras.layers import *
from keras.models import Sequential

model = Sequential()
model.add(LSTM(64,input_shape=(10,50),return_sequences=True))
model.add(Dropout(0.4))
model.add(LSTM(64,input_shape=(10,50)))
model.add(Dropout(0.3))
model.add(Dense(5))
model.add(Activation('softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 10, 64)            29440
#
#  dropout (Dropout)           (None, 10, 64)            0
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 5)                 325
#
#  activation (Activation)     (None, 5)                 0
#
# ...
# Total params: 62,789
# Trainable params: 62,789
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['acc'])
model.fit(emb_XT,YT,batch_size=32,epochs=40,shuffle=True,validation_split=0.1)
# Out:
# Epoch 1/40
# 4/4 [==============================] - 6s 424ms/step - loss: 1.6069 - acc: 0.2542 - val_loss: 1.6007 - val_acc: 0.2857
# Epoch 2/40
# 4/4 [==============================] - 0s 20ms/step - loss: 1.5304 - acc: 0.3051 - val_loss: 1.6120 - val_acc: 0.2857
# Epoch 3/40
# 4/4 [==============================] - 0s 52ms/step - loss: 1.5121 - acc: 0.2881 - val_loss: 1.6353 - val_acc: 0.2857
# Epoch 4/40
# 4/4 [==============================] - 0s 22ms/step - loss: 1.4675 - acc: 0.3220 - val_loss: 1.6162 - val_acc: 0.2857
# Epoch 5/40
# 4/4 [==============================] - 0s 51ms/step - loss: 1.4230 - acc: 0.3898 - val_loss: 1.5897 - val_acc: 0.1429
# Epoch 6/40
# 4/4 [==============================] - 0s 29ms/step - loss: 1.3582 - acc: 0.4322 - val_loss: 1.5280 - val_acc: 0.1429
# Epoch 7/40
# 4/4 [==============================] - 0s 45ms/step - loss: 1.3054 - acc: 0.4661 - val_loss: 1.4365 - val_acc: 0.2857
# Epoch 8/40
# ...

# %%
#Evaluating the model
model.evaluate(emb_Xt,Yt)
# Out:
# 2/2 [==============================] - 0s 8ms/step - loss: 1.3487 - acc: 0.5893
# [1.3486524820327759, 0.5892857313156128]

# %%
#Actual emojis
pred_x = model.predict(emb_Xt)
pred = np.argmax(pred_x,axis=1)
for i in range(5):
    print(''.join(Xt[i]))
    print(emoji.emojize(emoji_dictionary[str(np.argmax(Yt[i]))]))
    print(emoji.emojize(emoji_dictionary[str(pred[i])]))
# Out:
# 2/2 [==============================] - 1s 6ms/step
# Iwanttoeat
# 🍴
# 🍴
# hedidnotanswer
# 😓
# 😓
# hegotaraise
# 😁
# ❤️
# shegotmeapresent
# ❤️
# ❤️
# hahahaitwassofunny
# 😁
# 😁
